# %%
from tdmclient import ClientAsync
client = ClientAsync()
node = await client.wait_for_node()
await node.lock()
# Out:
# Node ad6b0acc-2bf0-4a27-bb7a-64d9d8bda21d

# %%
import matplotlib.pyplot as plt
from scipy.signal import find_peaks
import numpy as np
from tqdm import tqdm
import time
import KalmanFilter

# %%
from threading import Timer

class RepeatedTimer(object):
    def __init__(self, interval, function, *args, **kwargs):
        self._timer     = None
        self.interval   = interval
        self.function   = function
        self.args       = args
        self.kwargs     = kwargs
        self.is_running = False
        self.start()

    def _run(self):
        self.is_running = False
        self.start()
        self.function(*self.args, **self.kwargs)

    def start(self):
        if not self.is_running:
            self._timer = Timer(self.interval, self._run)
            self._timer.start()
            self.is_running = True

    def stop(self):
        self._timer.cancel()
        self.is_running = False

# %%
#Thymio control
def motors(l_speed=500, r_speed=500):
    return {
        "motor.left.target": [l_speed],
        "motor.right.target": [r_speed],
    }

async def forward(motor_speed):
    await node.set_variables(motors(motor_speed,motor_speed))

async def rotate(theta, motor_speed): #theta is in radians
    direction_rot=(theta>=0)-(theta<0)
    await node.set_variables(motors(motor_speed*direction_rot, -motor_speed*direction_rot))
    # wait time to get theta 1.44 is the factor to correct
    time=(theta)*100/motor_speed*1.44
    await(client.sleep(time))
    # stop the robot
    await node.set_variables(motors(0, 0))

async def stop_motor():
    await node.set_variables(motors(0,0))

async def get_proximity_values():
    # Wait for the Thymio node
    node = await client.wait_for_node()
    # Wait for the proximity sensor variables
    await node.wait_for_variables({"prox.horizontal"})
    # Get the proximity values : v: Stands for "variables" and is used to access the cached variable values.
    proximity_values = node.v.prox.horizontal
    # Return the value of the front proximity sensor (index 2)
    return proximity_values[0:5]

# Run the asynchronous function and print the result
proximity_values = await get_proximity_values()
print(f"Front Proximity Sensor Value: {proximity_values}")
# Out:
# Front Proximity Sensor Value: [0, 0, 0, 0, 0]

# %%
## Parameters for local navigation
threshold_obst = 3500 
threshold_loc = 2500
local_motor_speed = 100
threshold_obst_list = [3200, 3600, 3600, 3600, 3200]

async def local_navigation():
    threshold_obst = 1000
    threshold_loc = 800
    local_motor_speed = 100
    threshold_obst_list = [3200, 3600, 3600, 3600, 3200]
    sens = await get_proximity_values()

    # Follow the obstacle by the left
    if (sens[0] + sens[1]) > (sens[4] + sens[3]):
        await bypass('right', sens, threshold_loc, local_motor_speed)

    # Follow the obstacle by the right    
    else:
        await bypass('left', sens, threshold_loc, local_motor_speed)

async def bypass(leftright, sens, threshold_loc, local_motor_speed):
    if leftright == "right":
        while sum(sens[i] > threshold_obst for i in range(0, 5)) > 0:
            print("Turn right")
            await rotate(np.pi/6/2, local_motor_speed)
            #await asyncio.sleep(0.2)
            sens = await get_proximity_values()
            print(sens)

        while sens[0] > threshold_loc:
            await forward(local_motor_speed)
            #await asyncio.sleep(0.2)
            #time.sleep(0.2)
            sens = await get_proximity_values()
        
        

    elif leftright == "left":
        while sum(sens[i] > threshold_loc for i in range(0, 5)) > 0:
            print("Turn left")
            await rotate(-np.pi/6, local_motor_speed)
            #await asyncio.sleep(0.2)
            sens = await get_proximity_values()

        while sens[4] > threshold_loc:
            await forward(local_motor_speed)
            #await asyncio.sleep(0.2)
            #time.sleep(0.2)
            sens = await get_proximity_values()

    if(leftright=="right" and sens[0] < threshold_loc):
        await forward(local_motor_speed)
        time.sleep(2)
        await rotate(-np.pi/4, 100)
        awa
    

    await forward(local_motor_speed)
    #time.sleep(2)
    await stop_motor()

# %%
thymio_data = []
#acquire_data = True
Ts = 0.1

def get_data():
    thymio_data.append({"sensor":node["prox.horizontal"],
                        "left_speed":node["motor.left.speed"],
                        "right_speed":node["motor.right.speed"]})

async def get_speed():
    await node.wait_for_variables() # wait for Thymio variables values
    rt = RepeatedTimer(Ts, get_data) # it auto-starts, no need of rt.start()

    try:
        await client.sleep(Ts)
    finally:
        rt.stop() # better in a try/finally block to make sure the program ends!
        node.send_set_variables(motors(0, 0))

def pos_estimation(left_speed, right_speed, dt, pos0_x, pos0_y, theta0):
    real_thymio_speed = 25.5 #mm/s
    real_thymio_angular_speed = 0.38 #rad/s
    #speed estimation
    # speed_measured = (right_speed[-1] + left_speed[-1])/2
    # speed = (speed_measured * 52.5) / real_thymio_speed 
    # angular_speed_measured = (right_speed[-1] - left_speed[-1])/2
    # angular_speed = (angular_speed_measured * 50) / real_thymio_angular_speed
    speed_measured = (right_speed + left_speed)/2
    #speed = (speed_measured * 50) / real_thymio_speed 
    speed = (speed_measured * real_thymio_speed) / 50
    angular_speed_measured = (right_speed - left_speed)/2
    #angular_speed = (angular_speed_measured * 50) / real_thymio_angular_speed
    angular_speed = (angular_speed_measured * real_thymio_angular_speed) / 50
    #print("left ", left_speed, "right ", right_speed, "angular speed measured", angular_speed_measured, "angular speed ", angular_speed, "speed ", speed, "temps ", dt)

    #position estimation
    theta = theta0 + angular_speed * dt
    pos_x = pos0_x + speed * np.cos(theta) * dt
    pos_y = pos0_y + speed * np.sin(theta) * dt

    return speed, pos_x, pos_y, theta #rajouter angular speed

# %%
#MAIN CODE : 

#parameters
path_step = 0 #This is the index of where we are in the path.
path_coord = np.array([[1,2], [2,3], [3,4]])
b = np.array([3.2, 4.5])
epsilon = 0.5
local_obstacle = False
threshold_obst = 3500 #threshold for obstacle detection
pos_x, pos_y, theta = 0, 0, 0
speed_history = []
thymio_data.clear()

#to implement in a different way thanks to filtering : 
robot_position = 1
end_position = 2

async def main():

    global local_obstacle, pos_x, pos_y, theta, dt
    start_time = time.time()

    while(robot_position != end_position):
        sens = await get_proximity_values()
        if (sum(sens[i] > threshold_obst for i in range(0, 5)) > 0):
            local_obstacle = True

        if(local_obstacle):
            await local_navigation()
            start_time = time.time() #reset the timer          
        
        #if(find_index_path_if_close(path_coord,b,epsilon) and time.time-start_time>2): 
            #path_step=find_index_path_if_close(path_coord, position_robot, epsilon)
            #local_navigation=False

        if not local_obstacle: 
            node.send_set_variables(motors(50, 50))
            await get_speed()
            #if len(thymio_data) == 0: return pos0_x, pos0_y, theta0
    
            #current variables
            #left_speed = [x["left_speed"] for x in thymio_data]
            #right_speed = [x["right_speed"] for x in thymio_data]
            left_speed = node["motor.left.speed"]
            right_speed = node["motor.right.speed"]
            dt = time.time() - start_time 

            speed, pos_x, pos_y, theta = pos_estimation(left_speed, right_speed, dt, pos_x, pos_y, theta)
            start_time = time.time()
            speed_history.append(speed)
            print(round(pos_x/10,2), round(pos_y/10,2), round((theta*180)/np.pi,2))

await main()

std_speed = np.std(speed_history)
print("The speed variance in mm^2/s^2 is {}".format(std_speed))
# Out:
# left  0 right  0 angular speed measured 0.0 angular speed  0.0 speed  0.0 temps  0.5740997791290283
# 0.0 0.0 0.0
# left  0 right  0 angular speed measured 0.0 angular speed  0.0 speed  0.0 temps  0.10572695732116699
# 0.0 0.0 0.0
# left  34 right  34 angular speed measured 0.0 angular speed  0.0 speed  17.34 temps  0.10699200630187988
# 0.19 0.0 0.0
# left  39 right  39 angular speed measured 0.0 angular speed  0.0 speed  19.89 temps  0.11734986305236816
# 0.42 0.0 0.0
# left  45 right  41 angular speed measured -2.0 angular speed  -0.0152 speed  21.93 temps  0.10681390762329102
# 0.65 -0.0 -0.09
# left  43 right  40 angular speed measured -1.5 angular speed  -0.0114 speed  21.165 temps  0.10617971420288086
# 0.88 -0.0 -0.16
# left  40 right  39 angular speed measured -0.5 angular speed  -0.0038 speed  20.145 temps  0.10360288619995117
# 1.09 -0.0 -0.18
# left  47 right  46 angular speed measured -0.5 angular speed  -0.0038 speed  23.715 temps  0.10798978805541992
# 1.34 -0.0 -0.21
# left  55 right  49 angular speed measured -3.0 angular speed  -0.0228 speed  26.52 temps  0.10994529724121094
# 1.63 -0.0 -0.35
# left  60 right  56 angular speed measured -2.0 angular speed  -0.0152 speed  29.58 temps  0.10577678680419922
# 1.95 -0.01 -0.44
# left  51 right  68 angular speed measured 8.5 angular speed  0.0646 speed  30.345 temps  0.10926985740661621
# 2.28 -0.01 -0.04
# left  50 right  62 angular speed measured 6.0 angular speed  0.0456 speed  28.56 temps  0.10737204551696777
# 2.59 -0.01 0.24
# left  51 right  53 angular speed measured 1.0 angular speed  0.0076 speed  26.52 temps  0.16473078727722168
# 3.02 -0.0 0.31
# left  39 right  54 angular speed measured 7.5 angular speed  0.057 speed  23.715 temps  0.11056017875671387
# 3.28 -0.0 0.67
# left  53 right  42 angular speed measured -5.5 angular speed  -0.0418 speed  24.225 temps  0.10959506034851074
# 3.55 0.0 0.41
# left  50 right  44 angular speed measured -3.0 angular speed  -0.0228 speed  23.97 temps  0.11200785636901855
# 3.82 0.0 0.26
# left  50 right  44 angular speed measured -3.0 angular speed  -0.0228 speed  23.97 temps  0.10682797431945801
# 4.07 0.0 0.13
# left  43 right  30 angular speed measured -6.5 angular speed  -0.049400000000000006 speed  18.615 temps  0.11570906639099121
# 4.29 0.0 -0.2
# left  45 right  49 angular speed measured 2.0 angular speed  0.0152 speed  23.97 temps  0.11142492294311523
# 4.56 0.0 -0.11
# left  56 right  52 angular speed measured -2.0 angular speed  -0.0152 speed  27.54 temps  0.1073601245880127
# 4.85 0.0 -0.2
# left  57 right  56 angular speed measured -0.5 angular speed  -0.0038 speed  28.815 temps  0.10954594612121582
# 5.17 -0.0 -0.22
# left  43 right  54 angular speed measured 5.5 angular speed  0.0418 speed  24.735 temps  0.11101603507995605
# 5.44 0.0 0.04
# left  42 right  53 angular speed measured 5.5 angular speed  0.0418 speed  24.225 temps  0.10723209381103516
# 5.7 0.0 0.3
# left  41 right  48 angular speed measured 3.5 angular speed  0.026600000000000002 speed  22.695 temps  0.10934901237487793
# 5.95 0.0 0.47
# left  39 right  44 angular speed measured 2.5 angular speed  0.019 speed  21.165 temps  0.1078331470489502
# 6.18 0.01 0.58
# left  60 right  39 angular speed measured -10.5 angular speed  -0.07980000000000001 speed  25.245 temps  0.1079099178314209
# 6.45 0.01 0.09
# left  60 right  65 angular speed measured 2.5 angular speed  0.019 speed  31.875 temps  0.10686802864074707
# 6.79 0.01 0.21
# left  55 right  54 angular speed measured -0.5 angular speed  -0.0038 speed  27.795 temps  0.10929203033447266
# 7.1 0.01 0.18
# left  51 right  66 angular speed measured 7.5 angular speed  0.057 speed  29.835 temps  0.10718512535095215
# 7.42 0.01 0.53
# left  41 right  40 angular speed measured -0.5 angular speed  -0.0038 speed  20.655 temps  0.10764503479003906
# 7.64 0.01 0.51
# left  40 right  44 angular speed measured 2.0 angular speed  0.0152 speed  21.42 temps  0.10525012016296387
# 7.86 0.02 0.6
# left  51 right  67 angular speed measured 8.0 angular speed  0.0608 speed  30.09 temps  0.10841083526611328
# 8.19 0.02 0.98
# left  56 right  21 angular speed measured -17.5 angular speed  -0.133 speed  19.635 temps  0.10736298561096191
# 8.4 0.02 0.16
# left  46 right  43 angular speed measured -1.5 angular speed  -0.0114 speed  22.695 temps  0.12672710418701172
# 8.69 0.02 0.08
# left  59 right  26 angular speed measured -16.5 angular speed  -0.1254 speed  21.675 temps  0.11494898796081543
# 8.94 0.02 -0.75
# left  42 right  37 angular speed measured -2.5 angular speed  -0.019 speed  20.145 temps  0.10836195945739746
# 9.16 0.02 -0.87
# left  42 right  38 angular speed measured -2.0 angular speed  -0.0152 speed  20.4 temps  0.10773897171020508
# 9.38 0.01 -0.96
# left  57 right  54 angular speed measured -1.5 angular speed  -0.0114 speed  28.305 temps  0.11615109443664551
# 9.7 0.01 -1.04
# left  53 right  44 angular speed measured -4.5 angular speed  -0.0342 speed  24.735 temps  0.1118316650390625
# 9.98 0.0 -1.25
# left  41 right  58 angular speed measured 8.5 angular speed  0.0646 speed  25.245 temps  0.10863304138183594
# 10.25 -0.0 -0.85
# left  40 right  59 angular speed measured 9.5 angular speed  0.0722 speed  25.245 temps  0.10599899291992188
# 10.52 -0.01 -0.41
# left  55 right  49 angular speed measured -3.0 angular speed  -0.0228 speed  26.52 temps  0.10589885711669922
# 10.8 -0.01 -0.55
# left  56 right  41 angular speed measured -7.5 angular speed  -0.057 speed  24.735 temps  0.10923218727111816
# 11.07 -0.01 -0.91
# left  61 right  49 angular speed measured -6.0 angular speed  -0.0456 speed  28.05 temps  0.10545682907104492
# 11.37 -0.02 -1.18
# left  46 right  58 angular speed measured 6.0 angular speed  0.0456 speed  26.52 temps  0.1067819595336914
# 11.65 -0.02 -0.91
# left  48 right  39 angular speed measured -4.5 angular speed  -0.0342 speed  22.185 temps  0.10439586639404297
# 11.88 -0.03 -1.11
# left  40 right  44 angular speed measured 2.0 angular speed  0.0152 speed  21.42 temps  0.10700297355651855
# 12.11 -0.03 -1.02
# left  40 right  71 angular speed measured 15.5 angular speed  0.11779999999999999 speed  28.305 temps  0.1089942455291748
# 12.42 -0.03 -0.28
# left  54 right  38 angular speed measured -8.0 angular speed  -0.0608 speed  23.46 temps  0.10453295707702637
# 12.67 -0.04 -0.65
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# /Users/aubinsabatier/Desktop/EPFL Master/MA1/Basics of mobile robotics/Projet/MobileRoboticsG16/test_filtre.ipynb Cell 7 line 5
#      <a href='vscode-notebook-cell:/Users/aubinsabatier/Desktop/EPFL%20Master/MA1/Basics%20of%20mobile%20robotics/Projet/MobileRoboticsG16/test_filtre.ipynb#X11sZmlsZQ%3D%3D?line=49'>50</a>             speed_history.append(speed)
#      <a href='vscode-notebook-cell:/Users/aubinsabatier/Desktop/EPFL%20Master/MA1/Basics%20of%20mobile%20robotics/Projet/MobileRoboticsG16/test_filtre.ipynb#X11sZmlsZQ%3D%3D?line=50'>51</a>             print(round(pos_x/10,2), round(pos_y/10,2), round((theta*180)/np.pi,2))
# ---> <a href='vscode-notebook-cell:/Users/aubinsabatier/Desktop/EPFL%20Master/MA1/Basics%20of%20mobile%20robotics/Projet/MobileRoboticsG16/test_filtre.ipynb#X11sZmlsZQ%3D%3D?line=52'>53</a> await main()
#      <a href='vscode-notebook-cell:/Users/aubinsabatier/Desktop/EPFL%20Master/MA1/Basics%20of%20mobile%20robotics/Projet/MobileRoboticsG16/test_filtre.ipynb#X11sZmlsZQ%3D%3D?line=53'>54</a> var_speed = np.var(speed_history)
#      <a href='vscode-notebook-cell:/Users/aubinsabatier/Desktop/EPFL%20Master/MA1/Basics%20of%20mobile%20robotics/Projet/MobileRoboticsG16/test_filtre.ipynb#X11sZmlsZQ%3D%3D?line=54'>55</a> std_speed = np.std(speed_history)
#
# /Users/aubinsabatier/Desktop/EPFL Master/MA1/Basics of mobile robotics/Projet/MobileRoboticsG16/test_filtre.ipynb Cell 7 line 3
#      <a href='vscode-notebook-cell:/Users/aubinsabatier/Desktop/EPFL%20Master/MA1/Basics%20of%20mobile%20robotics/Projet/MobileRoboticsG16/test_filtre.ipynb#X11sZmlsZQ%3D%3D?line=35'>36</a> if not local_obstacle:
#      <a href='vscode-notebook-cell:/Users/aubinsabatier/Desktop/EPFL%20Master/MA1/Basics%20of%20mobile%20robotics/Projet/MobileRoboticsG16/test_filtre.ipynb#X11sZmlsZQ%3D%3D?line=36'>37</a>     node.send_set_variables(motors(50, 50))
# ---> <a href='vscode-notebook-cell:/Users/aubinsabatier/Desktop/EPFL%20Master/MA1/Basics%20of%20mobile%20robotics/Projet/MobileRoboticsG16/test_filtre.ipynb#X11sZmlsZQ%3D%3D?line=37'>38</a>     await get_speed()
#      <a href='vscode-notebook-cell:/Users/aubinsabatier/Desktop/EPFL%20Master/MA1/Basics%20of%20mobile%20robotics/Projet/MobileRoboticsG16/test_filtre.ipynb#X11sZmlsZQ%3D%3D?line=38'>39</a>     #if len(thymio_data) == 0: return pos0_x, pos0_y, theta0
#      <a href='vscode-notebook-cell:/Users/aubinsabatier/Desktop/EPFL%20Master/MA1/Basics%20of%20mobile%20robotics/Projet/MobileRoboticsG16/test_filtre.ipynb#X11sZmlsZQ%3D%3D?line=39'>40</a>
#      <a href='vscode-notebook-cell:/Users/aubinsabatier/Desktop/EPFL%20Master/MA1/Basics%20of%20mobile%20robotics/Projet/MobileRoboticsG16/test_filtre.ipynb#X11sZmlsZQ%3D%3D?line=40'>41</a>     #current variables
#      <a href='vscode-notebook-cell:/Users/aubinsabatier/Desktop/EPFL%20Master/MA1/Basics%20of%20mobile%20robotics/Projet/MobileRoboticsG16/test_filtre.ipynb#X11sZmlsZQ%3D%3D?line=41'>42</a>     #left_speed = [x["left_speed"] for x in thymio_data]
#      <a href='vscode-notebook-cell:/Users/aubinsabatier/Desktop/EPFL%20Master/MA1/Basics%20of%20mobile%20robotics/Projet/MobileRoboticsG16/test_filtre.ipynb#X11sZmlsZQ%3D%3D?line=42'>43</a>     #right_speed = [x["right_speed"] for x in thymio_data]
#      <a href='vscode-notebook-cell:/Users/aubinsabatier/Desktop/EPFL%20Master/MA1/Basics%20of%20mobile%20robotics/Projet/MobileRoboticsG16/test_filtre.ipynb#X11sZmlsZQ%3D%3D?line=43'>44</a>     left_speed = node["motor.left.speed"]
#
# /Users/aubinsabatier/Desktop/EPFL Master/MA1/Basics of mobile robotics/Projet/MobileRoboticsG16/test_filtre.ipynb Cell 7 line 1
#      <a href='vscode-notebook-cell:/Users/aubinsabatier/Desktop/EPFL%20Master/MA1/Basics%20of%20mobile%20robotics/Projet/MobileRoboticsG16/test_filtre.ipynb#X11sZmlsZQ%3D%3D?line=11'>12</a> rt = RepeatedTimer(Ts, get_data) # it auto-starts, no need of rt.start()
#      <a href='vscode-notebook-cell:/Users/aubinsabatier/Desktop/EPFL%20Master/MA1/Basics%20of%20mobile%20robotics/Projet/MobileRoboticsG16/test_filtre.ipynb#X11sZmlsZQ%3D%3D?line=13'>14</a> try:
# ---> <a href='vscode-notebook-cell:/Users/aubinsabatier/Desktop/EPFL%20Master/MA1/Basics%20of%20mobile%20robotics/Projet/MobileRoboticsG16/test_filtre.ipynb#X11sZmlsZQ%3D%3D?line=14'>15</a>     await client.sleep(Ts)
#      <a href='vscode-notebook-cell:/Users/aubinsabatier/Desktop/EPFL%20Master/MA1/Basics%20of%20mobile%20robotics/Projet/MobileRoboticsG16/test_filtre.ipynb#X11sZmlsZQ%3D%3D?line=15'>16</a> finally:
#      <a href='vscode-notebook-cell:/Users/aubinsabatier/Desktop/EPFL%20Master/MA1/Basics%20of%20mobile%20robotics/Projet/MobileRoboticsG16/test_filtre.ipynb#X11sZmlsZQ%3D%3D?line=16'>17</a>     rt.stop() # better in a try/finally block to make sure the program ends!
#
# File ~/anaconda3/envs/mobilerobotics/lib/python3.10/site-packages/tdmclient/clientasync.py:73, in ClientAsync.sleep(self, duration, wake)
#      71 if wake is not None and wake():
#      72     break
# ---> 73 yield
#
# CancelledError:

# %%
await node.set_variables(motors(0, 0))

# %%
KalmanFilter.kalman_filter(pos_x, pos_y, theta, q_nu, r_nu, speed_history, dt)

# %%
await tdmclient.notebook.stop()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/aubinsabatier/Desktop/EPFL Master/MA1/Basics of mobile robotics/Projet/MobileRoboticsG16/test_filtre.ipynb Cell 8 line 1
# ----> <a href='vscode-notebook-cell:/Users/aubinsabatier/Desktop/EPFL%20Master/MA1/Basics%20of%20mobile%20robotics/Projet/MobileRoboticsG16/test_filtre.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> await tdmclient.notebook.stop()
#
# File ~/anaconda3/envs/mobilerobotics/lib/python3.10/site-packages/tdmclient/notebook/private.py:130, in stop()
#     128 # undo ipython configuration
#     129 ip = get_ipython()
# --> 130 ip.events.unregister("pre_run_cell", _pre_run_cell)
#     131 ip.events.unregister("post_run_cell", _post_run_cell)
#     133 # disconnect node, tdm and zeroconf
#
# File ~/anaconda3/envs/mobilerobotics/lib/python3.10/site-packages/IPython/core/events.py:72, in EventManager.unregister(self, event, function)
#      69 if function in self.callbacks[event]:
#      70     return self.callbacks[event].remove(function)
# ---> 72 raise ValueError('Function {!r} is not registered as a {} callback'.format(function, event))
#
# ValueError: Function <function _pre_run_cell at 0x7f8be4798d30> is not registered as a pre_run_cell callback

# %%
await node.set_variables(motors(50, 55))
await client.sleep(10)
await node.set_variables(motors(0, 0))

# %%
await node.set_variables(motors(-50, 55))
await client.sleep(10)
await node.set_variables(motors(0, 0))
